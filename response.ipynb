# %%
data = dict(
    user='fstuser1',
    password='P@ssw0rdJames'
)

# %%
from IPython.display import clear_output
from matplotlib import pyplot as plt
import collections
import numpy as np
# %matplotlib notebook
import requests
from random import random, randint
# from IPython import display

# %%
from random import random, randint
from IPython.display import clear_output
from matplotlib import pyplot as plt
import collections
import numpy as np
import requests
from IPython import display

# %%
def live_plot(s1,data,figsize=(7,5), title=''):
    response = s1.get('http://127.0.0.1:5000/userHome/view', json=data)
    data['pikachu'].append(response.json().get('pikachu'))
    data['bulbasaur'].append(response.json().get('bulbasaur'))
    data['charmander'].append(response.json().get('charmander'))
    data['squirtle'].append(response.json().get('squirtle'))
    # plt.figure(figsize=figsize)
    # figure, axis = plt.subplots(ncols=2)
    # print(data)
    for label,data in data.items():
        plt.plot(data, label=label)
    
    # plt.title(title)
    # plt.grid(True)
    # plt.xlabel('epoch')
    # plt.legend(loc='center left') # the plot evolves to the right
    plt.show()

# %%
#s1 session is for fstuser1
s1 = requests.Session()
data = dict(
    user='fstuser1',
    password='P@ssw0rdJames'
)
response1 = s1.get('http://127.0.0.1:5000/login', json=data)
print(response1, response1.text)

# response1 = s1.get('http://127.0.0.1:5000/userHome/view', json=data)
# print(response1, response1.text)

#s1 session is for fstuser1
s1 = requests.Session()
data = dict(
    user='fstuser1',
    password='P@ssw0rdJames'
)
response1 = s1.get('http://127.0.0.1:5000/login', json=data)

#s2 session is for fstuser2
s2 = requests.Session()
data = dict(
    user='fstuser2',
    password='P@ssw0rdJames'
)
response1 = s2.get('http://127.0.0.1:5000/login', json=data)

s1data = collections.defaultdict(list)
s2data = collections.defaultdict(list)

# figure define 
display.clear_output(wait=True)
# figure, axis = plt.subplots()
live_plot(s1,s1data)
live_plot(s2,s2data)
time = 0.15
plt.pause(time)
# time.sleep(1)
cardType = ["pikachu", "bulbasaur", "charmander","squirtle"]
for i in range(100):
    # main function start random choose card and whether to buy or sell
    data = {
        "cardType":cardType[randint(0,3)],
        "num":randint(6, 10),
        '$perCard':randint(5, 20)
    }
    # action = randint(1,2)
    action = 1
    actionstr = ""
    if(action == 1):
        actionstr = "buy"
    else:
        actionstr = "sell"
    
    response2 = s1.get('http://127.0.0.1:5000/userHome/'+ actionstr, json=data)


    response1 = s2.get('http://127.0.0.1:5000/login', json=data)
    # print(response1, response1.text)
    data = {
        "cardType":cardType[randint(0,3)],
        "num":randint(6, 10),
        '$perCard':randint(5, 20)
    }
    # print(data)
    # action = randint(1,2)
    action = 2
    actionstr = ""
    if(action == 1):
        actionstr = "buy"
    else:
        actionstr = "sell"
    
    response2 = s2.get('http://127.0.0.1:5000/userHome/' + actionstr, json=data)
    # print(response2, response2.text)
    display.clear_output(wait=True)
    live_plot(s1,s1data)
    live_plot(s2,s2data)
    plt.pause(time)
    # live_plot(s2,s2data,axis[1],figure)
   
# t.joing()

# %%
# Out:
# <div id='3282a4cb-ab45-4fd5-bb6b-239046a081f5'></div>

# %%
display.clear_output(wait=True)

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.axis([0, 10, 0, 1])

for i in range(10):
    y = np.random.random()
    plt.scatter(i, y)
    plt.pause(0.05)

plt.show()
